# %%
import pandas as pd
from time import sleep

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import pickle
# transformer?
# other preprocessing?

# %%
tracks_and_features_df = pd.read_csv('tracks_and_features.csv')
features_df = pd.read_csv('features.csv')

# %%
tracks_and_features_df.head(3)
# Out:
#                 artist_id           artist_name                track_id  \
# 0  5ypoEsxvCfwoM8dWqpRQhq              Shamoryo  6YLlHjowYdcrULkRk4r4Ga
# 1  2WBJQGf1bT1kxuoqziH5g4  Purple Disco Machine  2F2p7b5Xq20mRyEeWYaeUF
# 2  3MyFDtqB80WZvbtCZRsekM              Bakermat  17B9XlyyYDKkTmPay4z02V
#
#                              track_name album_release_date  \
# 0                                 Jubel         1900-01-01
# 1  Substitution (feat. Julian Perretta)         2023-03-30
# 2                                Baianá         2020-10-09
#
#   album_release_date_precision  is_explicit  duration_ms  popularity  \
# 0                          day        False       197044          41
# 1                          day        False       181477          81
# 2                          day        False       180842          65
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.691  ...      0.686000          0.076700     0.269    0.117
# 1         0.690  ...      0.009030          0.000016     0.188    0.713
# 2         0.587  ...      0.000754          0.668000     0.543    0.466
#
#      tempo  duration_ms.1  time_signature  \
# 0  125.008         197045               4
# 1  124.018         181478               4
# 2  121.964         180843               4
#
#                                           track_href  album_release_year  \
# 0  https://api.spotify.com/v1/tracks/6YLlHjowYdcr...                1900
# 1  https://api.spotify.com/v1/tracks/2F2p7b5Xq20m...                2023
# 2  https://api.spotify.com/v1/tracks/17B9XlyyYDKk...                2020
#
#    album_release_decade
# 0                  1900
# 1                  2020
# 2                  2020
#
# [3 rows x 25 columns]

# %%
features_df.head(3)
# Out:
#    is_explicit  duration_ms  duration_ms.1  popularity  danceability  energy  \
# 0        False       197044         197045          41         0.691   0.519
# 1        False       181477         181478          81         0.690   0.890
# 2        False       180842         180843          65         0.587   0.722
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    0    -7.770     1       0.0353      0.686000          0.076700     0.269
# 1    0    -4.866     0       0.0507      0.009030          0.000016     0.188
# 2    2    -6.983     0       0.0709      0.000754          0.668000     0.543
#
#    valence    tempo  duration_ms.2  duration_ms.3  time_signature
# 0    0.117  125.008         197044         197045               4
# 1    0.713  124.018         181477         181478               4
# 2    0.466  121.964         180842         180843               4

# %%
audio_features_model_on = ['is_explicit','popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature']
features_df = features_df[audio_features_model_on]

# %%
km100 = KMeans(100)
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features_df)
km100.fit(scaled_features)
# Out:
# KMeans(n_clusters=100)

# %%
scaled_features
# Out:
# array([[0.        , 0.41      , 0.70010132, ..., 0.117     , 0.51779013,
#         0.8       ],
#        [0.        , 0.81      , 0.69908815, ..., 0.713     , 0.51368949,
#         0.8       ],
#        [0.        , 0.65      , 0.59473151, ..., 0.466     , 0.50518171,
#         0.8       ],
#        ...,
#        [0.        , 0.23      , 0.47922999, ..., 0.781     , 0.4122464 ,
#         0.8       ],
#        [1.        , 0.24      , 0.39412361, ..., 0.173     , 0.42849569,
#         0.8       ],
#        [0.        , 0.24      , 0.15096251, ..., 0.134     , 0.42066306,
#         0.8       ]])

# %%
km100.labels_
# Out:
# array([33, 84,  9, ..., 12, 75, 49])

# %%
tracks_clustered_df = tracks_and_features_df.copy()
tracks_clustered_df['cluster_km100'] = km100.labels_
tracks_clustered_df[tracks_clustered_df['cluster_km100']==4].sample(1)
# Out:
#                     artist_id   artist_name                track_id  \
# 17983  0ZrpamOxcZybMHGg1AYtHP  Robin Thicke  4ORp5huJChm7E6QZpA1482
#
#            track_name album_release_date album_release_date_precision  \
# 17983  Take Me Higher         2021-01-20                          day
#
#        is_explicit  duration_ms  popularity  danceability  ...  \
# 17983        False       244679          36         0.805  ...
#
#        instrumentalness  liveness  valence   tempo  duration_ms.1  \
# 17983           0.00299     0.112    0.627  107.01         244680
#
#        time_signature                                         track_href  \
# 17983               4  https://api.spotify.com/v1/tracks/4ORp5huJChm7...
#
#        album_release_year  album_release_decade  cluster_km100
# 17983                2021                  2020              4
#
# [1 rows x 26 columns]

# %%
# tracks_clustered_df.to_csv('tracks_clustered_df.csv', index=False) # save our dataset with cluster info
# save the model with pickle
# save any transformers pickle


# loading and saving with pickle:

# import pickle

# a = {'hello': 'world'}

# saving/dumping
# with open('filename.pickle', 'wb') as handle:
#     pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# print(a == b)

with open('model_km100.pickle', 'wb') as handle:
    pickle.dump(km100, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('scaler.pickle', 'wb') as handle:
    pickle.dump(scaler, handle, protocol=pickle.HIGHEST_PROTOCOL)
